# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt

from IPython.display import Image

# %%
lena = plt.imread('lena_std.tif')
aviao = plt.imread('f16.tif')

# %%
def scale_img(img, scale):
    return np.repeat(np.repeat(img[::scale,::scale], axis=0, repeats=scale), axis=1, repeats=scale).astype(np.uint8)

# %%
scales = [int(2**i) for i in range(10)]

with imageio.get_writer("gif_lena.gif") as writer:
    [writer.append_data(scale_img(lena, j)) for j in scales]
    [writer.append_data(scale_img(aviao, j)) for j in reversed(scales)]

# %%
display(Image(filename="gif_lena.gif"))
